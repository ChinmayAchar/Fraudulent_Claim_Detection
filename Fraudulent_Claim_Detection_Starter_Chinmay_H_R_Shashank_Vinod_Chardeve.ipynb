# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv('/content/insurance_claims.csv')

# %%
# Check at the first few entries
display(df.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# Inspect the shape of the dataset
display(df.shape)
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        909 non-null    object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB
# None

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
display(df.isnull().sum())
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values
# Drop the '_c39' column as it has all null values
df = df.drop('_c39', axis=1)

# Fill null values in 'authorities_contacted' with a placeholder
df['authorities_contacted'] = df['authorities_contacted'].fillna('Not Contacted')

# Verify that null values have been handled
display(df.isnull().sum())
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# dtype: int64

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].value_counts())
    print("-" * 30)
# Out:
# Column: months_as_customer
# months_as_customer
# 194    8
# 285    7
# 254    7
# 101    7
# 128    7
#       ..
# 372    1
# 213    1
# 240    1
# 50     1
# 17     1
# Name: count, Length: 391, dtype: int64
# ------------------------------
# Column: age
# age
# 43    49
# 39    48
# 41    45
# 34    44
# 31    42
# 38    42
# 30    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 44    32
# 36    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 55    14
# 49    14
# 25    14
# 50    13
# 53    13
# 61    10
# 24    10
# 54    10
# 51     9
# 60     9
# 56     8
# 58     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: count, dtype: int64
# ------------------------------
# Column: policy_number
# policy_number
# 556080    1
# 521585    1
# 342868    1
# 687698    1
# 227811    1
#          ..
# 842643    1
# 214618    1
# 543610    1
# 636550    1
# 485665    1
# Name: count, Length: 1000, dtype: int64
# ------------------------------
# Column: policy_bind_date
# policy_bind_date
# 1992-08-05    3
# 2006-01-01    3
# 1992-04-28    3
# 1996-07-07    2
# 2002-07-16    2
#              ..
# 1999-02-18    1
# 1997-10-30    1
# 1999-11-29    1
# 2013-07-07    1
# 1991-08-02    1
# Name: count, Length: 951, dtype: int64
# ------------------------------
# Column: policy_state
# policy_state
# OH    352
# IL    338
# IN    310
# Name: count, dtype: int64
# ------------------------------
# Column: policy_csl
# policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: count, dtype: int64
# ------------------------------
# Column: policy_deductable
# policy_deductable
# 1000    351
# 500     342
# 2000    307
# Name: count, dtype: int64
# ------------------------------
# Column: policy_annual_premium
# policy_annual_premium
# 1362.87    2
# 1073.83    2
# 1389.13    2
# 1524.45    2
# 1074.07    2
#           ..
# 1437.33    1
# 988.29     1
# 1238.89    1
# 1384.64    1
# 1554.64    1
# Name: count, Length: 991, dtype: int64
# ------------------------------
# Column: umbrella_limit
# umbrella_limit
#  0           798
#  6000000      57
#  5000000      46
#  4000000      39
#  7000000      29
#  3000000      12
#  8000000       8
#  9000000       5
#  2000000       3
#  10000000      2
# -1000000       1
# Name: count, dtype: int64
# ------------------------------
# Column: insured_zip
# insured_zip
# 456602    2
# 469429    2
# 446895    2
# 431202    2
# 477695    2
#          ..
# 450339    1
# 476502    1
# 600561    1
# 600754    1
# 457535    1
# Name: count, Length: 995, dtype: int64
# ------------------------------
# Column: insured_sex
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
# ------------------------------
# Column: insured_education_level
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
# ------------------------------
# Column: insured_occupation
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# priv-house-serv      71
# other-service        71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
# ------------------------------
# Column: insured_hobbies
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# camping           55
# golf              55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# base-jumping      49
# skydiving         49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: count, dtype: int64
# ------------------------------
# Column: insured_relationship
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: count, dtype: int64
# ------------------------------
# Column: capital-gains
# capital-gains
# 0        508
# 46300      5
# 68500      4
# 51500      4
# 67800      3
#         ...
# 30800      1
# 42300      1
# 12800      1
# 69900      1
# 50300      1
# Name: count, Length: 338, dtype: int64
# ------------------------------
# Column: capital-loss
# capital-loss
#  0        475
# -53700      5
# -50300      5
# -31700      5
# -61400      4
#          ...
# -65500      1
# -15900      1
# -61200      1
# -32200      1
# -82100      1
# Name: count, Length: 354, dtype: int64
# ------------------------------
# Column: incident_date
# incident_date
# 2015-02-02    28
# 2015-02-17    26
# 2015-01-07    25
# 2015-01-24    24
# 2015-02-04    24
# 2015-01-10    24
# 2015-01-19    23
# 2015-01-08    22
# 2015-01-13    21
# 2015-01-30    21
# 2015-02-22    20
# 2015-02-12    20
# 2015-02-06    20
# 2015-01-31    20
# 2015-01-14    19
# 2015-01-12    19
# 2015-02-23    19
# 2015-02-21    19
# 2015-01-01    19
# 2015-01-21    19
# 2015-02-28    18
# 2015-01-18    18
# 2015-01-03    18
# 2015-01-20    18
# 2015-02-25    18
# 2015-02-14    18
# 2015-02-01    18
# 2015-01-09    17
# 2015-02-24    17
# 2015-02-26    17
# 2015-02-08    17
# 2015-01-06    17
# 2015-02-13    16
# 2015-02-05    16
# 2015-02-16    16
# 2015-01-16    16
# 2015-02-15    16
# 2015-01-15    15
# 2015-01-28    15
# 2015-02-18    15
# 2015-01-17    15
# 2015-02-20    14
# 2015-02-27    14
# 2015-01-22    14
# 2015-02-03    13
# 2015-01-23    13
# 2015-02-09    13
# 2015-01-27    13
# 2015-01-04    12
# 2015-03-01    12
# 2015-01-29    11
# 2015-01-02    11
# 2015-01-26    11
# 2015-02-11    10
# 2015-01-25    10
# 2015-02-10    10
# 2015-02-19    10
# 2015-02-07    10
# 2015-01-11     9
# 2015-01-05     7
# Name: count, dtype: int64
# ------------------------------
# Column: incident_type
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64
# ------------------------------
# Column: collision_type
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: count, dtype: int64
# ------------------------------
# Column: incident_severity
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: count, dtype: int64
# ------------------------------
# Column: authorities_contacted
# authorities_contacted
# Police           292
# Fire             223
# Other            198
# Ambulance        196
# Not Contacted     91
# Name: count, dtype: int64
# ------------------------------
# Column: incident_state
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: count, dtype: int64
# ------------------------------
# Column: incident_city
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: count, dtype: int64
# ------------------------------
# Column: incident_location
# incident_location
# 1416 Cherokee Ridge    1
# 9935 4th Drive         1
# 6608 MLK Hwy           1
# 7121 Francis Lane      1
# 6956 Maple Drive       1
#                       ..
# 6655 5th Drive         1
# 5971 5th Hwy           1
# 1558 1st Ridge         1
# 3066 Francis Ave       1
# 4872 Rock Ridge        1
# Name: count, Length: 1000, dtype: int64
# ------------------------------
# Column: incident_hour_of_the_day
# incident_hour_of_the_day
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 4     46
# 10    46
# 13    46
# 6     44
# 14    43
# 9     43
# 21    42
# 18    41
# 7     40
# 12    40
# 19    40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: count, dtype: int64
# ------------------------------
# Column: number_of_vehicles_involved
# number_of_vehicles_involved
# 1    581
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
# ------------------------------
# Column: property_damage
# property_damage
# ?      360
# NO     338
# YES    302
# Name: count, dtype: int64
# ------------------------------
# Column: bodily_injuries
# bodily_injuries
# 0    340
# 2    332
# 1    328
# Name: count, dtype: int64
# ------------------------------
# Column: witnesses
# witnesses
# 1    258
# 2    250
# 0    249
# 3    243
# Name: count, dtype: int64
# ------------------------------
# Column: police_report_available
# police_report_available
# ?      343
# NO     343
# YES    314
# Name: count, dtype: int64
# ------------------------------
# Column: total_claim_amount
# total_claim_amount
# 59400    5
# 44200    4
# 3190     4
# 75400    4
# 70400    4
#         ..
# 4800     1
# 80080    1
# 7590     1
# 45180    1
# 89520    1
# Name: count, Length: 763, dtype: int64
# ------------------------------
# Column: injury_claim
# injury_claim
# 0        25
# 640       7
# 480       7
# 5540      5
# 860       5
#          ..
# 14560     1
# 7980      1
# 3880      1
# 13200     1
# 6790      1
# Name: count, Length: 638, dtype: int64
# ------------------------------
# Column: property_claim
# property_claim
# 0        19
# 860       6
# 11080     5
# 480       5
# 650       5
#          ..
# 10400     1
# 4020      1
# 7910      1
# 14560     1
# 6430      1
# Name: count, Length: 626, dtype: int64
# ------------------------------
# Column: vehicle_claim
# vehicle_claim
# 5040     7
# 3360     6
# 4720     5
# 44800    5
# 3600     5
#         ..
# 42390    1
# 79560    1
# 32900    1
# 22160    1
# 32830    1
# Name: count, Length: 726, dtype: int64
# ------------------------------
# Column: auto_make
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: count, dtype: int64
# ------------------------------
# Column: auto_model
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# Legacy            32
# A5                32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# E400              27
# 95                27
# F150              27
# Grand Cherokee    25
# 93                25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# TL                20
# Impreza           20
# Corolla           20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: count, dtype: int64
# ------------------------------
# Column: auto_year
# auto_year
# 1995    56
# 1999    55
# 2005    54
# 2006    53
# 2011    53
# 2007    52
# 2003    51
# 2009    50
# 2010    50
# 2013    49
# 2002    49
# 2015    47
# 1997    46
# 2012    46
# 2008    45
# 2014    44
# 2001    42
# 2000    42
# 1998    40
# 2004    39
# 1996    37
# Name: count, dtype: int64
# ------------------------------
# Column: fraud_reported
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64
# ------------------------------

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
empty_columns = df.columns[df.isnull().all()]
df.drop(columns=empty_columns, inplace=True)
display(df.isnull().sum())
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# dtype: int64

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
df = df[df['umbrella_limit'] >= 0].copy()

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
df = df.drop(['policy_number', 'insured_zip', 'incident_location'], axis=1)

# %%
# Check the dataset
display(df.head())
display(df.shape)
# Out:
#    months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                 328   48       2014-10-17           OH    250/500
# 1                 228   42       2006-06-27           IN    250/500
# 2                 134   29       2000-09-06           OH    100/300
# 3                 256   41       1990-05-25           IL    250/500
# 4                 228   44       2014-06-06           IL   500/1000
#
#    policy_deductable  policy_annual_premium  umbrella_limit insured_sex  \
# 0               1000                1406.91               0        MALE
# 1               2000                1197.22         5000000        MALE
# 2               2000                1413.14         5000000      FEMALE
# 3               2000                1415.74         6000000      FEMALE
# 4               1000                1583.91         6000000        MALE
#
#   insured_education_level  ... witnesses police_report_available  \
# 0                      MD  ...         2                     YES
# 1                      MD  ...         0                       ?
# 2                     PhD  ...         3                      NO
# 3                     PhD  ...         2                      NO
# 4               Associate  ...         1                      NO
#
#   total_claim_amount  injury_claim  property_claim vehicle_claim  auto_make  \
# 0              71610          6510           13020         52080       Saab
# 1               5070           780             780          3510   Mercedes
# 2              34650          7700            3850         23100      Dodge
# 3              63400          6340            6340         50720  Chevrolet
# 4               6500          1300             650          4550     Accura
#
#   auto_model auto_year fraud_reported
# 0        92x      2004              Y
# 1       E400      2007              Y
# 2        RAM      2007              N
# 3      Tahoe      2014              Y
# 4        RSX      2009              N
#
# [5 rows x 36 columns]
# (999, 36)

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
df['policy_bind_date'] = pd.to_datetime(df['policy_bind_date'])
df['incident_date'] = pd.to_datetime(df['incident_date'])

# %%
# Check the features of the data again
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_bind_date             999 non-null    datetime64[ns]
#  3   policy_state                 999 non-null    object
#  4   policy_csl                   999 non-null    object
#  5   policy_deductable            999 non-null    int64
#  6   policy_annual_premium        999 non-null    float64
#  7   umbrella_limit               999 non-null    int64
#  8   insured_sex                  999 non-null    object
#  9   insured_education_level      999 non-null    object
#  10  insured_occupation           999 non-null    object
#  11  insured_hobbies              999 non-null    object
#  12  insured_relationship         999 non-null    object
#  13  capital-gains                999 non-null    int64
#  14  capital-loss                 999 non-null    int64
#  15  incident_date                999 non-null    datetime64[ns]
#  16  incident_type                999 non-null    object
#  17  collision_type               999 non-null    object
#  18  incident_severity            999 non-null    object
#  19  authorities_contacted        999 non-null    object
#  20  incident_state               999 non-null    object
#  21  incident_city                999 non-null    object
#  22  incident_hour_of_the_day     999 non-null    int64
#  23  number_of_vehicles_involved  999 non-null    int64
#  24  property_damage              999 non-null    object
#  25  bodily_injuries              999 non-null    int64
#  26  witnesses                    999 non-null    int64
#  27  police_report_available      999 non-null    object
#  28  total_claim_amount           999 non-null    int64
#  29  injury_claim                 999 non-null    int64
#  30  property_claim               999 non-null    int64
#  31  vehicle_claim                999 non-null    int64
#  32  auto_make                    999 non-null    object
#  33  auto_model                   999 non-null    object
#  34  auto_year                    999 non-null    int64
#  35  fraud_reported               999 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(15), object(18)
# memory usage: 288.8+ KB
# None

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
X = df.drop('fraud_reported', axis=1)

# Put the target variable in y
y = df['fraud_reported']

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Reset index for all train and test sets
X_train = X_train.reset_index(drop=True)
X_validation = X_validation.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_validation = y_validation.reset_index(drop=True)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numerical_cols_train = X_train.select_dtypes(include=['int64', 'float64']).columns
display(numerical_cols_train)
# Out:
# Index(['months_as_customer', 'age', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'capital-gains',
#        'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year'],
#       dtype='object')

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
for col in numerical_cols_train:
    plt.figure(figsize=(10, 6))
    sns.histplot(X_train[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
correlation_matrix = X_train[numerical_cols_train].corr()

# Plot Heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Features (Training Data)')
plt.show()

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
plt.figure(figsize=(4, 3))
sns.countplot(x=y_train)
plt.title('Class Balance of Fraud Reported (Training Data)')
plt.xlabel('Fraud Reported')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
def target_likelihood_analysis(df, categorical_cols, target):

    for col in categorical_cols:
        print(f"Target likelihood for: {col}")
        likelihood = df.groupby(col)[target].value_counts(normalize=True).unstack()
        display(likelihood)
        print("-" * 50)

# Identify categorical columns
categorical_cols_train = X_train.select_dtypes(include='object').columns

# Combine X_train and y_train for analysis
train_data_for_analysis = pd.concat([X_train, y_train], axis=1)

# Perform target likelihood analysis
target_likelihood_analysis(train_data_for_analysis, categorical_cols_train, 'fraud_reported')
# Out:
# Target likelihood for: policy_state
# fraud_reported         N         Y
# policy_state
# IL              0.756303  0.243697
# IN              0.754545  0.245455
# OH              0.746888  0.253112
# --------------------------------------------------
# Target likelihood for: policy_csl
# fraud_reported         N         Y
# policy_csl
# 100/300         0.732000  0.268000
# 250/500         0.748936  0.251064
# 500/1000        0.780374  0.219626
# --------------------------------------------------
# Target likelihood for: insured_sex
# fraud_reported         N         Y
# insured_sex
# FEMALE          0.750670  0.249330
# MALE            0.754601  0.245399
# --------------------------------------------------
# Target likelihood for: insured_education_level
# fraud_reported                  N         Y
# insured_education_level
# Associate                0.765766  0.234234
# College                  0.753086  0.246914
# High School              0.790909  0.209091
# JD                       0.716814  0.283186
# MD                       0.736842  0.263158
# Masters                  0.747475  0.252525
# PhD                      0.755556  0.244444
# --------------------------------------------------
# Target likelihood for: insured_occupation
# fraud_reported             N         Y
# insured_occupation
# adm-clerical        0.829787  0.170213
# armed-forces        0.739130  0.260870
# craft-repair        0.698113  0.301887
# exec-managerial     0.660714  0.339286
# farming-fishing     0.718750  0.281250
# handlers-cleaners   0.857143  0.142857
# machine-op-inspct   0.753846  0.246154
# other-service       0.812500  0.187500
# priv-house-serv     0.820000  0.180000
# prof-specialty      0.809524  0.190476
# protective-serv     0.756757  0.243243
# sales               0.727273  0.272727
# tech-support        0.740741  0.259259
# transport-moving    0.655172  0.344828
# --------------------------------------------------
# Target likelihood for: insured_hobbies
# fraud_reported          N         Y
# insured_hobbies
# base-jumping     0.763158  0.236842
# basketball       0.888889  0.111111
# board-games      0.781250  0.218750
# bungie-jumping   0.825000  0.175000
# camping          0.891892  0.108108
# chess            0.093750  0.906250
# cross-fit        0.240000  0.760000
# dancing          0.882353  0.117647
# exercise         0.846154  0.153846
# golf             0.925000  0.075000
# hiking           0.750000  0.250000
# kayaking         0.888889  0.111111
# movies           0.848485  0.151515
# paintball        0.744681  0.255319
# polo             0.687500  0.312500
# reading          0.775510  0.224490
# skydiving        0.777778  0.222222
# sleeping         0.791667  0.208333
# video-games      0.764706  0.235294
# yachting         0.702703  0.297297
# --------------------------------------------------
# Target likelihood for: insured_relationship
# fraud_reported               N         Y
# insured_relationship
# husband               0.789474  0.210526
# not-in-family         0.760331  0.239669
# other-relative        0.700787  0.299213
# own-child             0.826446  0.173554
# unmarried             0.705882  0.294118
# wife                  0.728070  0.271930
# --------------------------------------------------
# Target likelihood for: incident_type
# fraud_reported                   N         Y
# incident_type
# Multi-vehicle Collision   0.721649  0.278351
# Parked Car                0.907692  0.092308
# Single Vehicle Collision  0.712766  0.287234
# Vehicle Theft             0.918033  0.081967
# --------------------------------------------------
# Target likelihood for: collision_type
# fraud_reported          N         Y
# collision_type
# ?                0.912698  0.087302
# Front Collision  0.710983  0.289017
# Rear Collision   0.702830  0.297170
# Side Collision   0.739362  0.260638
# --------------------------------------------------
# Target likelihood for: incident_severity
# fraud_reported            N         Y
# incident_severity
# Major Damage       0.390625  0.609375
# Minor Damage       0.909091  0.090909
# Total Loss         0.849741  0.150259
# Trivial Damage     0.934426  0.065574
# --------------------------------------------------
# Target likelihood for: authorities_contacted
# fraud_reported                N         Y
# authorities_contacted
# Ambulance              0.683824  0.316176
# Fire                   0.719745  0.280255
# Not Contacted          0.911765  0.088235
# Other                  0.714286  0.285714
# Police                 0.797980  0.202020
# --------------------------------------------------
# Target likelihood for: incident_state
# fraud_reported         N         Y
# incident_state
# NC              0.686747  0.313253
# NY              0.787356  0.212644
# OH              0.578947  0.421053
# PA              0.684211  0.315789
# SC              0.700565  0.299435
# VA              0.733333  0.266667
# WV              0.848684  0.151316
# --------------------------------------------------
# Target likelihood for: incident_city
# fraud_reported         N         Y
# incident_city
# Arlington       0.701923  0.298077
# Columbus        0.727273  0.272727
# Hillsdale       0.750000  0.250000
# Northbend       0.800000  0.200000
# Northbrook      0.786517  0.213483
# Riverwood       0.787879  0.212121
# Springfield     0.723810  0.276190
# --------------------------------------------------
# Target likelihood for: property_damage
# fraud_reported          N         Y
# property_damage
# ?                0.709677  0.290323
# NO               0.823770  0.176230
# YES              0.719807  0.280193
# --------------------------------------------------
# Target likelihood for: police_report_available
# fraud_reported                  N         Y
# police_report_available
# ?                        0.744939  0.255061
# NO                       0.744856  0.255144
# YES                      0.770335  0.229665
# --------------------------------------------------
# Target likelihood for: auto_make
# fraud_reported         N         Y
# auto_make
# Accura          0.860000  0.140000
# Audi            0.673077  0.326923
# BMW             0.720000  0.280000
# Chevrolet       0.727273  0.272727
# Dodge           0.811321  0.188679
# Ford            0.703704  0.296296
# Honda           0.709677  0.290323
# Jeep            0.750000  0.250000
# Mercedes        0.705882  0.294118
# Nissan          0.827586  0.172414
# Saab            0.764706  0.235294
# Suburu          0.761905  0.238095
# Toyota          0.765957  0.234043
# Volkswagen      0.725000  0.275000
# --------------------------------------------------
# Target likelihood for: auto_model
# fraud_reported         N         Y
# auto_model
# 3 Series        0.923077  0.076923
# 92x             0.736842  0.263158
# 93              0.692308  0.307692
# 95              0.842105  0.157895
# A3              0.714286  0.285714
# A5              0.625000  0.375000
# Accord          0.800000  0.200000
# C300            0.666667  0.333333
# CRV             0.888889  0.111111
# Camry           0.764706  0.235294
# Civic           0.500000  0.500000
# Corolla         0.833333  0.166667
# E400            0.708333  0.291667
# Escape          0.764706  0.235294
# F150            0.636364  0.363636
# Forrestor       0.666667  0.333333
# Fusion          0.733333  0.266667
# Grand Cherokee  0.625000  0.375000
# Highlander      0.722222  0.277778
# Impreza         0.785714  0.214286
# Jetta           0.714286  0.285714
# Legacy          0.840000  0.160000
# M5              0.700000  0.300000
# MDX             0.827586  0.172414
# ML350           0.733333  0.266667
# Malibu          1.000000       NaN
# Maxima          0.625000  0.375000
# Neon            0.807692  0.192308
# Passat          0.736842  0.263158
# Pathfinder      0.954545  0.045455
# RAM             0.814815  0.185185
# RSX             0.909091  0.090909
# Silverado       0.562500  0.437500
# TL              0.900000  0.100000
# Tahoe           0.600000  0.400000
# Ultima          0.850000  0.150000
# Wrangler        0.821429  0.178571
# X5              0.705882  0.294118
# X6              0.500000  0.500000
# --------------------------------------------------

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
for col in numerical_cols_train:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=y_train, y=X_train[col])
    plt.title(f'{col} vs Fraud Reported (Training Data)')
    plt.xlabel('Fraud Reported')
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data
ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data

# Calculate the difference between incident date and policy bind date
X_train_resampled['policy_incident_duration'] = (X_train_resampled['incident_date'] - X_train_resampled['policy_bind_date']).dt.days
X_validation['policy_incident_duration'] = (X_validation['incident_date'] - X_validation['policy_bind_date']).dt.days

# You can explore creating other features as well

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
X_train_resampled = X_train_resampled.drop(['policy_bind_date', 'incident_date'], axis=1)
X_validation = X_validation.drop(['policy_bind_date', 'incident_date'], axis=1)

# %%
# Check the data
display(X_train_resampled.head())
display(X_train_resampled.shape)
display(X_validation.head())
display(X_validation.shape)
# Out:
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 129   28           OH   500/1000               1000
# 1                 210   41           IL   500/1000                500
# 2                  85   25           IN    250/500                500
# 3                 429   56           OH    250/500               1000
# 4                 106   31           IL   500/1000               2000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1377.94               0        MALE                 Masters
# 1                1222.75               0        MALE             High School
# 2                1259.02               0      FEMALE                      JD
# 3                1127.89         6000000        MALE               Associate
# 4                1320.75               0      FEMALE                      JD
#
#   insured_occupation  ... witnesses police_report_available  \
# 0  machine-op-inspct  ...         3                       ?
# 1    exec-managerial  ...         0                      NO
# 2       tech-support  ...         2                       ?
# 3  machine-op-inspct  ...         0                     YES
# 4    farming-fishing  ...         3                     YES
#
#    total_claim_amount  injury_claim property_claim vehicle_claim auto_make  \
# 0               44640          9920           4960         29760    Toyota
# 1               81070         14740          14740         51590       BMW
# 2                5640           940            940          3760    Nissan
# 3               39480          6580           6580         26320    Suburu
# 4               45630          5070           5070         35490    Accura
#
#   auto_model auto_year policy_incident_duration
# 0      Camry      2005                     9129
# 1         X5      2001                      819
# 2     Ultima      2005                     2357
# 3  Forrestor      2002                     5891
# 4        MDX      2011                     6198
#
# [5 rows x 34 columns]
# (1052, 34)
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 458   59           IN    100/300               1000
# 1                 235   42           IN    250/500                500
# 2                 182   38           OH   500/1000               2000
# 3                  35   35           IL    100/300               2000
# 4                 229   37           IN   500/1000               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1685.69               0      FEMALE             High School
# 1                1072.62               0      FEMALE                 Masters
# 2                1441.06               0      FEMALE                 Masters
# 3                1117.42               0      FEMALE                     PhD
# 4                1331.94               0      FEMALE                 Masters
#
#   insured_occupation  ... witnesses police_report_available  \
# 0    protective-serv  ...         2                     YES
# 1  machine-op-inspct  ...         1                     YES
# 2       armed-forces  ...         3                     YES
# 3    protective-serv  ...         2                      NO
# 4    farming-fishing  ...         2                     YES
#
#    total_claim_amount  injury_claim property_claim vehicle_claim   auto_make  \
# 0               71800         14360          14360         43080        Jeep
# 1               69100          6910           6910         55280      Toyota
# 2               89650          8150          16300         65200       Dodge
# 3               53190          5910          11820         35460  Volkswagen
# 4               54560          9920           9920         34720        Saab
#
#        auto_model auto_year policy_incident_duration
# 0  Grand Cherokee      1995                     2175
# 1      Highlander      2006                     8915
# 2             RAM      2005                     2099
# 3           Jetta      1996                     4540
# 4              95      2004                     7289
#
# [5 rows x 34 columns]
# (300, 34)

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information

# Identify categorical columns again after dropping date columns
categorical_cols = X_train_resampled.select_dtypes(include='object').columns

# Example: Combine low frequency categories in 'insured_occupation'
occupation_counts = X_train_resampled['insured_occupation'].value_counts()
low_freq_occupations = occupation_counts[occupation_counts < 30].index
X_train_resampled['insured_occupation'] = X_train_resampled['insured_occupation'].replace(low_freq_occupations, 'Other')
X_validation['insured_occupation'] = X_validation['insured_occupation'].replace(low_freq_occupations, 'Other')

# %%
# Example: Combine low frequency categories in 'insured_hobbies'
hobbies_counts = X_train_resampled['insured_hobbies'].value_counts()
low_freq_hobbies = hobbies_counts[hobbies_counts < 30].index
X_train_resampled['insured_hobbies'] = X_train_resampled['insured_hobbies'].replace(low_freq_hobbies, 'Other')
X_validation['insured_hobbies'] = X_validation['insured_hobbies'].replace(low_freq_hobbies, 'Other')

# %%
# Example: Combine low frequency categories in 'auto_make'
auto_make_counts = X_train_resampled['auto_make'].value_counts()
low_freq_auto_make = auto_make_counts[auto_make_counts < 30].index
X_train_resampled['auto_make'] = X_train_resampled['auto_make'].replace(low_freq_auto_make, 'Other')
X_validation['auto_make'] = X_validation['auto_make'].replace(low_freq_auto_make, 'Other')

# %%
# Example: Combine low frequency categories in 'auto_model'
auto_model_counts = X_train_resampled['auto_model'].value_counts()
low_freq_auto_model = auto_model_counts[auto_model_counts < 20].index
X_train_resampled['auto_model'] = X_train_resampled['auto_model'].replace(low_freq_auto_model, 'Other')
X_validation['auto_model'] = X_validation['auto_model'].replace(low_freq_auto_model, 'Other')

# %%
# Handle '?' in collision_type, property_damage, police_report_available
X_train_resampled['collision_type'] = X_train_resampled['collision_type'].replace('?', 'Unknown')
X_validation['collision_type'] = X_validation['collision_type'].replace('?', 'Unknown')

X_train_resampled['property_damage'] = X_train_resampled['property_damage'].replace('?', 'Unknown')
X_validation['property_damage'] = X_validation['property_damage'].replace('?', 'Unknown')

X_train_resampled['police_report_available'] = X_train_resampled['police_report_available'].replace('?', 'Unknown')
X_validation['police_report_available'] = X_validation['police_report_available'].replace('?', 'Unknown')

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
categorical_cols_for_dummies = X_train_resampled.select_dtypes(include='object').columns
display(categorical_cols_for_dummies)
# Out:
# Index(['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'property_damage', 'police_report_available', 'auto_make',
#        'auto_model'],
#       dtype='object')

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data
X_train_resampled = pd.get_dummies(X_train_resampled, columns=categorical_cols_for_dummies, drop_first=True)

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data
X_validation = pd.get_dummies(X_validation, columns=categorical_cols_for_dummies, drop_first=True)

# Align columns - crucial after get_dummies
train_cols = list(X_train_resampled.columns)
validation_cols = list(X_validation.columns)

missing_in_validation = set(train_cols) - set(validation_cols)
for c in missing_in_validation:
    X_validation[c] = 0

missing_in_train = set(validation_cols) - set(train_cols)
for c in missing_in_train:
    X_train_resampled[c] = 0

X_validation = X_validation[train_cols]

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
y_train_resampled = y_train_resampled.map({'N': 0, 'Y': 1})

# Create dummy variable for dependent feature in validation data
y_validation = y_validation.map({'N': 0, 'Y': 1})

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler

# Identify numerical columns after dummy variable creation
numerical_cols_resampled = X_train_resampled.select_dtypes(include=['int64', 'float64']).columns

# Scale the numeric features present in the training data
scaler = StandardScaler()
X_train_resampled[numerical_cols_resampled] = scaler.fit_transform(X_train_resampled[numerical_cols_resampled])

# Scale the numeric features present in the validation data
X_validation[numerical_cols_resampled] = scaler.transform(X_validation[numerical_cols_resampled])

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
# Apply RFECV to identify the most relevant features
logreg = LogisticRegression()
rfecv = RFECV(estimator=logreg, step=1, cv=5, scoring='accuracy')
rfecv.fit(X_train_resampled, y_train_resampled)
# Out:
# RFECV(cv=5, estimator=LogisticRegression(), scoring='accuracy')

# %%
# Display the features ranking by RFECV in a DataFrame
feature_ranking = pd.DataFrame({'Features': X_train_resampled.columns, 'Ranking': rfecv.ranking_})
display(feature_ranking.sort_values(by='Ranking'))
# Out:
#                                 Features  Ranking
# 45                 insured_hobbies_chess        1
# 46             insured_hobbies_cross-fit        1
# 44               insured_hobbies_camping        1
# 58           insured_hobbies_video-games        1
# 32  insured_occupation_handlers-cleaners        1
# ..                                   ...      ...
# 81                     incident_state_SC      117
# 11                    total_claim_amount      118
# 13                        property_claim      119
# 77          authorities_contacted_Police      120
# 17                       policy_state_IN      121
#
# [135 rows x 2 columns]

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col = X_train_resampled.columns[rfecv.support_]
display(col)
# Out:
# Index(['insured_occupation_handlers-cleaners', 'insured_hobbies_camping',
#        'insured_hobbies_chess', 'insured_hobbies_cross-fit',
#        'insured_hobbies_video-games', 'incident_severity_Minor Damage',
#        'incident_severity_Total Loss', 'incident_severity_Trivial Damage',
#        'auto_model_Civic', 'auto_model_Fusion', 'auto_model_Grand Cherokee',
#        'auto_model_Legacy', 'auto_model_Other', 'auto_model_Pathfinder',
#        'auto_model_X5'],
#       dtype='object')

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV
X_train_selected = X_train_resampled[col].astype(int)

# %%
# Import statsmodels and add constant
import statsmodels.api as sm

X_train_selected = sm.add_constant(X_train_selected)

# Check the data
display(X_train_selected.head())
# Out:
#    const  insured_occupation_handlers-cleaners  insured_hobbies_camping  \
# 0    1.0                                 False                    False
# 1    1.0                                 False                    False
# 2    1.0                                 False                    False
# 3    1.0                                 False                    False
# 4    1.0                                 False                    False
#
#    insured_hobbies_chess  insured_hobbies_cross-fit  \
# 0                  False                      False
# 1                  False                      False
# 2                  False                      False
# 3                  False                      False
# 4                  False                      False
#
#    insured_hobbies_video-games  incident_severity_Minor Damage  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                            True
# 4                         True                           False
#
#    incident_severity_Total Loss  incident_severity_Trivial Damage  \
# 0                         False                             False
# 1                          True                             False
# 2                         False                              True
# 3                         False                             False
# 4                          True                             False
#
#    auto_model_Civic  auto_model_Fusion  auto_model_Grand Cherokee  \
# 0             False              False                      False
# 1             False              False                      False
# 2             False              False                      False
# 3             False              False                      False
# 4             False              False                      False
#
#    auto_model_Legacy  auto_model_Other  auto_model_Pathfinder  auto_model_X5
# 0              False             False                  False          False
# 1              False             False                  False           True
# 2              False             False                  False          False
# 3              False             False                  False          False
# 4              False             False                  False          False

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary
logreg_model = sm.Logit(y_train_resampled, X_train_selected).fit()
display(logreg_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.429416
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                 1052
# Model:                          Logit   Df Residuals:                     1037
# Method:                           MLE   Df Model:                           14
# Date:                Mon, 15 Sep 2025   Pseudo R-squ.:                  0.3805
# Time:                        12:26:29   Log-Likelihood:                -451.75
# converged:                       True   LL-Null:                       -729.19
# Covariance Type:            nonrobust   LLR p-value:                2.082e-109
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# insured_occupation_handlers-cleaners    -0.2633      0.429     -0.613      0.540      -1.105       0.578
# insured_hobbies_camping                 -0.0437      0.430     -0.102      0.919      -0.886       0.799
# insured_hobbies_chess                    5.9445      0.641      9.270      0.000       4.688       7.201
# insured_hobbies_cross-fit                3.8601      0.484      7.983      0.000       2.912       4.808
# insured_hobbies_video-games              1.7163      0.357      4.801      0.000       1.016       2.417
# incident_severity_Minor Damage          -2.8309      0.253    -11.187      0.000      -3.327      -2.335
# incident_severity_Total Loss            -2.0957      0.227     -9.226      0.000      -2.541      -1.650
# incident_severity_Trivial Damage        -3.0083      0.525     -5.729      0.000      -4.037      -1.979
# auto_model_Civic                         2.8796      0.576      4.998      0.000       1.750       4.009
# auto_model_Fusion                       -0.0893      0.607     -0.147      0.883      -1.279       1.100
# auto_model_Grand Cherokee                1.9657      0.544      3.612      0.000       0.899       3.032
# auto_model_Legacy                       -0.0621      0.544     -0.114      0.909      -1.128       1.004
# auto_model_Other                         0.3935      0.224      1.756      0.079      -0.046       0.833
# auto_model_Pathfinder                   -1.1861      0.699     -1.696      0.090      -2.556       0.184
# auto_model_X5                           -0.5416      0.758     -0.715      0.475      -2.026       0.943
# ========================================================================================================
# """

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present
vif_data = pd.DataFrame()
vif_data['feature'] = X_train_selected.columns
vif_data['VIF'] = [variance_inflation_factor(X_train_selected.values, i) for i in range(len(X_train_selected.columns))]

display(vif_data)
# Out:
#                                  feature       VIF
# 0   insured_occupation_handlers-cleaners  1.053472
# 1                insured_hobbies_camping  1.053225
# 2                  insured_hobbies_chess  1.236994
# 3              insured_hobbies_cross-fit  1.099394
# 4            insured_hobbies_video-games  1.071853
# 5         incident_severity_Minor Damage  1.287605
# 6           incident_severity_Total Loss  1.269828
# 7       incident_severity_Trivial Damage  1.037901
# 8                       auto_model_Civic  1.029819
# 9                      auto_model_Fusion  1.038032
# 10             auto_model_Grand Cherokee  1.030492
# 11                     auto_model_Legacy  1.034009
# 12                      auto_model_Other  1.180717
# 13                 auto_model_Pathfinder  1.036266
# 14                         auto_model_X5  1.099474

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data
y_train_pred_proba = logreg_model.predict(X_train_selected)

# Reshape it into an array
y_train_pred_proba = y_train_pred_proba.values.reshape(-1, 1)

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model
y_train_pred_df = pd.DataFrame({'Actual': y_train_resampled, 'Predicted_proba': y_train_pred_proba.flatten()})

# Create new column indicating predicted classifications based on a cutoff value of 0.5
y_train_pred_df['Predicted'] = y_train_pred_df['Predicted_proba'].apply(lambda x: 1 if x > 0.5 else 0)

display(y_train_pred_df.head())
# Out:
#    Actual  Predicted_proba  Predicted
# 0       0         0.500000          0
# 1       0         0.066773          0
# 2       0         0.047050          0
# 3       0         0.055679          0
# 4       0         0.406262          0

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the accuracy of the model
display(metrics.accuracy_score(y_train_pred_df.Actual, y_train_pred_df.Predicted))
# Out:
# 0.6834600760456274

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
conf_matrix = metrics.confusion_matrix(y_train_pred_df.Actual, y_train_pred_df.Predicted)
display(conf_matrix)
# Out:
# array([[499,  27],
#        [306, 220]])

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN = conf_matrix[0, 0]
FP = conf_matrix[0, 1]
FN = conf_matrix[1, 0]
TP = conf_matrix[1, 1]

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = TP / (TP + FN)
display(f"Sensitivity: {sensitivity}")

# Calculate the specificity
specificity = TN / (TN + FP)
display(f"Specificity: {specificity}")

# Calculate Precision
precision = TP / (TP + FP)
display(f"Precision: {precision}")

# Calculate Recall
recall = sensitivity  # Recall is the same as sensitivity
display(f"Recall: {recall}")

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
display(f"F1 Score: {f1_score}")
# Out:
# 'Sensitivity: 0.41825095057034223'
# 'Specificity: 0.9486692015209125'
# 'Precision: 0.8906882591093117'
# 'Recall: 0.41825095057034223'
# 'F1 Score: 0.5692108667529108'

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
from sklearn.metrics import roc_curve, auc

# Define ROC function
def plot_roc_curve(fpr, tpr, roc_auc):
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.show()

# %%
# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_train_pred_df.Actual, y_train_pred_df.Predicted_proba)
roc_auc = auc(fpr, tpr)

# Call the ROC function
plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance
numbers = [float(x) / 10 for x in range(10)]
for number in numbers:
    y_train_pred_df[number] = y_train_pred_df.Predicted_proba.apply(lambda x: 1 if x > number else 0)

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
cutoff_df = pd.DataFrame(columns=['prob', 'accuracy', 'sensitivity', 'specificity'])
for number in numbers:
    tn, fp, fn, tp = metrics.confusion_matrix(y_train_pred_df.Actual, y_train_pred_df[number]).ravel()
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    cutoff_df.loc[number] = [number, accuracy, sensitivity, specificity]
display(cutoff_df)
# Out:
#      prob  accuracy  sensitivity  specificity
# 0.0   0.0  0.500000     1.000000     0.000000
# 0.1   0.1  0.743346     0.969582     0.517110
# 0.2   0.2  0.857414     0.939163     0.775665
# 0.3   0.3  0.883080     0.935361     0.830798
# 0.4   0.4  0.884030     0.933460     0.834601
# 0.5   0.5  0.683460     0.418251     0.948669
# 0.6   0.6  0.648289     0.321293     0.975285
# 0.7   0.7  0.646388     0.313688     0.979087
# 0.8   0.8  0.637833     0.294677     0.980989
# 0.9   0.9  0.610266     0.231939     0.988593

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
cutoff_df.plot.line(x='prob', y=['accuracy', 'sensitivity', 'specificity'])
plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
optimal_cutoff = 0.2
y_train_pred_df['Final_Predicted'] = y_train_pred_df['Predicted_proba'].apply(lambda x: 1 if x > optimal_cutoff else 0)

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
display(metrics.accuracy_score(y_train_pred_df.Actual, y_train_pred_df.Final_Predicted))
# Out:
# 0.8574144486692015

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
conf_matrix_optimal_cutoff = metrics.confusion_matrix(y_train_pred_df.Actual, y_train_pred_df.Final_Predicted)
display(conf_matrix_optimal_cutoff)
# Out:
# array([[408, 118],
#        [ 32, 494]])

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN_optimal = conf_matrix_optimal_cutoff[0, 0]
FP_optimal = conf_matrix_optimal_cutoff[0, 1]
FN_optimal = conf_matrix_optimal_cutoff[1, 0]
TP_optimal = conf_matrix_optimal_cutoff[1, 1]

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity
sensitivity_optimal = TP_optimal / (TP_optimal + FN_optimal)
display(f"Sensitivity (Optimal Cutoff): {sensitivity_optimal}")

# Calculate the specificity
specificity_optimal = TN_optimal / (TN_optimal + FP_optimal)
display(f"Specificity (Optimal Cutoff): {specificity_optimal}")

# Calculate Precision
precision_optimal = TP_optimal / (TP_optimal + FP_optimal)
display(f"Precision (Optimal Cutoff): {precision_optimal}")

# Calculate Recall
recall_optimal = sensitivity_optimal  # Recall is the same as sensitivity
display(f"Recall (Optimal Cutoff): {recall_optimal}")

# Calculate F1 Score
f1_score_optimal = 2 * (precision_optimal * recall_optimal) / (precision_optimal + recall_optimal)
display(f"F1 Score (Optimal Cutoff): {f1_score_optimal}")
# Out:
# 'Sensitivity (Optimal Cutoff): 0.9391634980988594'
# 'Specificity (Optimal Cutoff): 0.7756653992395437'
# 'Precision (Optimal Cutoff): 0.8071895424836601'
# 'Recall (Optimal Cutoff): 0.9391634980988594'
# 'F1 Score (Optimal Cutoff): 0.8681898066783831'

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_train_pred_df.Actual, y_train_pred_df.Predicted_proba)

plt.figure()
plt.plot(recall, precision, marker='.')
plt.title('Precision-Recall Curve (Training Data)')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
rf_model = RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Fit the base random forest model to get feature importances
rf_model.fit(X_train_resampled, y_train_resampled)

# Get feature importance scores from the trained model
feature_importances = rf_model.feature_importances_

# Create a DataFrame to visualise the importance scores
feature_importance_df = pd.DataFrame({'Features': X_train_resampled.columns, 'Importance': feature_importances})
display(feature_importance_df.sort_values(by='Importance', ascending=False).head(10)) # Display top 10
# Out:
#                           Features  Importance
# 71  incident_severity_Minor Damage    0.072886
# 11              total_claim_amount    0.050267
# 45           insured_hobbies_chess    0.046791
# 14                   vehicle_claim    0.042989
# 72    incident_severity_Total Loss    0.041385
# 13                  property_claim    0.039054
# 0               months_as_customer    0.034906
# 3            policy_annual_premium    0.032092
# 12                    injury_claim    0.030709
# 16        policy_incident_duration    0.030586

# %%
# Select features with high importance scores (e.g., importance > 0.01)
important_features = feature_importance_df[feature_importance_df['Importance'] > 0.01]['Features']
display(important_features)

# Create a new training data with only the selected features
X_train_important = X_train_resampled[important_features]
# Out:
# 0                 months_as_customer
# 1                                age
# 3              policy_annual_premium
# 4                     umbrella_limit
# 5                      capital-gains
# 6                       capital-loss
# 7           incident_hour_of_the_day
# 9                    bodily_injuries
# 10                         witnesses
# 11                total_claim_amount
# 12                      injury_claim
# 13                    property_claim
# 14                     vehicle_claim
# 15                         auto_year
# 16          policy_incident_duration
# 45             insured_hobbies_chess
# 46         insured_hobbies_cross-fit
# 71    incident_severity_Minor Damage
# 72      incident_severity_Total Loss
# 83                 incident_state_WV
# Name: Features, dtype: object

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
rf_model.fit(X_train_important, y_train_resampled)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_train_pred_rf = rf_model.predict(X_train_important)

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
display(metrics.accuracy_score(y_train_resampled, y_train_pred_rf))
# Out:
# 1.0

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
conf_matrix_rf = metrics.confusion_matrix(y_train_resampled, y_train_pred_rf)
display(conf_matrix_rf)
# Out:
# array([[526,   0],
#        [  0, 526]])

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN_rf = conf_matrix_rf[0, 0]
FP_rf = conf_matrix_rf[0, 1]
FN_rf = conf_matrix_rf[1, 0]
TP_rf = conf_matrix_rf[1, 1]

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_rf = TP_rf / (TP_rf + FN_rf)
display(f"Sensitivity (Random Forest): {sensitivity_rf}")

# Calculate the specificity
specificity_rf = TN_rf / (TN_rf + FP_rf)
display(f"Specificity (Random Forest): {specificity_rf}")

# Calculate Precision
precision_rf = TP_rf / (TP_rf + FP_rf)
display(f"Precision (Random Forest): {precision_rf}")

# Calculate Recall
recall_rf = sensitivity_rf  # Recall is the same as sensitivity
display(f"Recall (Random Forest): {recall_rf}")

# Calculate F1 Score
f1_score_rf = 2 * (precision_rf * recall_rf) / (precision_rf + recall_rf)
display(f"F1 Score (Random Forest): {f1_score_rf}")
# Out:
# 'Sensitivity (Random Forest): 1.0'
# 'Specificity (Random Forest): 1.0'
# 'Precision (Random Forest): 1.0'
# 'Recall (Random Forest): 1.0'
# 'F1 Score (Random Forest): 1.0'

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting
cv_scores = cross_val_score(rf_model, X_train_important, y_train_resampled, cv=5)
display(f"Cross-validation scores: {cv_scores}")
display(f"Mean cross-validation accuracy: {cv_scores.mean()}")
# Out:
# 'Cross-validation scores: [0.88625592 0.91943128 0.94285714 0.92380952 0.93809524]'
# 'Mean cross-validation accuracy: 0.9220898217106749'

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train_important, y_train_resampled)

# Best Hyperparameters
display("Best hyperparameters found: ", grid_search.best_params_)
display("Best cross-validation score: ", grid_search.best_score_)
# Out:
# 'Best hyperparameters found: '
# {'max_depth': 15,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}
# 'Best cross-validation score: '
# np.float64(0.9277815391559467)

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
rf_model_tuned = RandomForestClassifier(**grid_search.best_params_, random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Fit the tuned model on the training data
rf_model_tuned.fit(X_train_important, y_train_resampled)

# Make predictions on training data
y_train_pred_rf_tuned = rf_model_tuned.predict(X_train_important)

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
display(metrics.accuracy_score(y_train_resampled, y_train_pred_rf_tuned))
# Out:
# 1.0

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_rf_tuned = metrics.confusion_matrix(y_train_resampled, y_train_pred_rf_tuned)
display(conf_matrix_rf_tuned)
# Out:
# array([[526,   0],
#        [  0, 526]])

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN_rf_tuned = conf_matrix_rf_tuned[0, 0]
FP_rf_tuned = conf_matrix_rf_tuned[0, 1]
FN_rf_tuned = conf_matrix_rf_tuned[1, 0]
TP_rf_tuned = conf_matrix_rf_tuned[1, 1]

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_rf_tuned = TP_rf_tuned / (TP_rf_tuned + FN_rf_tuned)
display(f"Sensitivity (Tuned Random Forest): {sensitivity_rf_tuned}")

# Calculate the specificity
specificity_rf_tuned = TN_rf_tuned / (TN_rf_tuned + FP_rf_tuned)
display(f"Specificity (Tuned Random Forest): {specificity_rf_tuned}")

# Calculate Precision
precision_rf_tuned = TP_rf_tuned / (TP_rf_tuned + FP_rf_tuned)
display(f"Precision (Tuned Random Forest): {precision_rf_tuned}")

# Calculate Recall
recall_rf_tuned = sensitivity_rf_tuned  # Recall is the same as sensitivity
display(f"Recall (Tuned Random Forest): {recall_rf_tuned}")

# Calculate F1-Score
f1_score_rf_tuned = 2 * (precision_rf_tuned * recall_rf_tuned) / (precision_rf_tuned + recall_rf_tuned)
display(f"F1 Score (Tuned Random Forest): {f1_score_rf_tuned}")
# Out:
# 'Sensitivity (Tuned Random Forest): 1.0'
# 'Specificity (Tuned Random Forest): 1.0'
# 'Precision (Tuned Random Forest): 1.0'
# 'Recall (Tuned Random Forest): 1.0'
# 'F1 Score (Tuned Random Forest): 1.0'

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data
X_validation_selected = X_validation[col].astype(int)

# Add constant to X_validation
X_validation_selected = sm.add_constant(X_validation_selected, has_constant='add')

# Ensure columns are in the same order as in the training data
X_validation_selected = X_validation_selected[X_train_selected.columns]

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'
y_validation_pred_proba_logreg = logreg_model.predict(X_validation_selected)

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data
y_validation_pred_df_logreg = pd.DataFrame({'Actual': y_validation, 'Predicted_proba': y_validation_pred_proba_logreg})
display(y_validation_pred_df_logreg.head())
# Out:
#    Actual  Predicted_proba
# 0       0         0.467543
# 1       0         0.109513
# 2       0         0.109513
# 3       0         0.055679
# 4       0         0.109513

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
y_validation_pred_df_logreg['Final_Predicted'] = y_validation_pred_df_logreg['Predicted_proba'].apply(lambda x: 1 if x > optimal_cutoff else 0)

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy
display(metrics.accuracy_score(y_validation_pred_df_logreg.Actual, y_validation_pred_df_logreg.Final_Predicted))
# Out:
# 0.7633333333333333

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_validation_logreg = metrics.confusion_matrix(y_validation_pred_df_logreg.Actual, y_validation_pred_df_logreg.Final_Predicted)
display(conf_matrix_validation_logreg)
# Out:
# array([[164,  62],
#        [  9,  65]])

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN_validation_logreg = conf_matrix_validation_logreg[0, 0]
FP_validation_logreg = conf_matrix_validation_logreg[0, 1]
FN_validation_logreg = conf_matrix_validation_logreg[1, 0]
TP_validation_logreg = conf_matrix_validation_logreg[1, 1]

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_validation_logreg = TP_validation_logreg / (TP_validation_logreg + FN_validation_logreg)
display(f"Sensitivity (Validation - Logistic Regression): {sensitivity_validation_logreg}")

# Calculate the specificity
specificity_validation_logreg = TN_validation_logreg / (TN_validation_logreg + FP_validation_logreg)
display(f"Specificity (Validation - Logistic Regression): {specificity_validation_logreg}")

# Calculate Precision
precision_validation_logreg = TP_validation_logreg / (TP_validation_logreg + FP_validation_logreg)
display(f"Precision (Validation - Logistic Regression): {precision_validation_logreg}")

# Calculate Recall
recall_validation_logreg = sensitivity_validation_logreg  # Recall is the same as sensitivity
display(f"Recall (Validation - Logistic Regression): {recall_validation_logreg}")

# Calculate F1 Score
f1_score_validation_logreg = 2 * (precision_validation_logreg * recall_validation_logreg) / (precision_validation_logreg + recall_validation_logreg)
display(f"F1 Score (Validation - Logistic Regression): {f1_score_validation_logreg}")
# Out:
# 'Sensitivity (Validation - Logistic Regression): 0.8783783783783784'
# 'Specificity (Validation - Logistic Regression): 0.7256637168141593'
# 'Precision (Validation - Logistic Regression): 0.5118110236220472'
# 'Recall (Validation - Logistic Regression): 0.8783783783783784'
# 'F1 Score (Validation - Logistic Regression): 0.6467661691542288'

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data
X_validation_important = X_validation[important_features]

# Make predictions on the validation data
y_validation_pred_rf = rf_model_tuned.predict(X_validation_important)

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy
display(metrics.accuracy_score(y_validation, y_validation_pred_rf))
# Out:
# 0.81

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_validation_rf = metrics.confusion_matrix(y_validation, y_validation_pred_rf)
display(conf_matrix_validation_rf)
# Out:
# array([[196,  30],
#        [ 27,  47]])

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN_validation_rf = conf_matrix_validation_rf[0, 0]
FP_validation_rf = conf_matrix_validation_rf[0, 1]
FN_validation_rf = conf_matrix_validation_rf[1, 0]
TP_validation_rf = conf_matrix_validation_rf[1, 1]

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate Sensitivity
sensitivity_validation_rf = TP_validation_rf / (TP_validation_rf + FN_validation_rf)
display(f"Sensitivity (Validation - Random Forest): {sensitivity_validation_rf}")

# Calculate Specificity
specificity_validation_rf = TN_validation_rf / (TN_validation_rf + FP_validation_rf)
display(f"Specificity (Validation - Random Forest): {specificity_validation_rf}")

# Calculate Precision
precision_validation_rf = TP_validation_rf / (TP_validation_rf + FP_validation_rf)
display(f"Precision (Validation - Random Forest): {precision_validation_rf}")

# Calculate Recall
recall_validation_rf = sensitivity_validation_rf  # Recall is the same as sensitivity
display(f"Recall (Validation - Random Forest): {recall_validation_rf}")

# Calculate F1-score
f1_score_validation_rf = 2 * (precision_validation_rf * recall_validation_rf) / (precision_validation_rf + recall_validation_rf)
display(f"F1 Score (Validation - Random Forest): {f1_score_validation_rf}")
# Out:
# 'Sensitivity (Validation - Random Forest): 0.6351351351351351'
# 'Specificity (Validation - Random Forest): 0.8672566371681416'
# 'Precision (Validation - Random Forest): 0.6103896103896104'
# 'Recall (Validation - Random Forest): 0.6351351351351351'
# 'F1 Score (Validation - Random Forest): 0.6225165562913907'

# %% [markdown]
# ## **Evaluation and Conclusion**
# Write the conclusion.
